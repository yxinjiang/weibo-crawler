# %%
from weibo import *

# %%
def is_date(since_date):
    """判断日期格式是否正确"""
    try:
        datetime.strptime(since_date, "%Y-%m-%d %H:%M:%S")
        return True
    except ValueError:
        return False

# %%
config = get_config()
since_date = config["since_date"]

wb = Weibo(config)

# %%
user_config = wb.user_config_list[0]
wb.initialize_info(user_config)
wb.get_user_info()
wb.get_pages()
# Out:
# 茶美丽的追剧日常 信息写入csv文件完毕，保存路径: g:\Study\weibo\weibo-crawler\weibo\users.csv
# 准备搜集 茶美丽的追剧日常 的微博
# Progress:   0%|          | 0/197 [00:00<?, ?it/s]
# 已获取用户 茶美丽的追剧日常 的微博，内容为 #迪丽热巴流光闪烁花絮#这就是所谓的缘分吧[滑稽]
# 已获取用户 茶美丽的追剧日常 的微博，内容为 #光渊#听说这个剧被点名批评了啊但播还是可以播的。
# 已获取用户 茶美丽的追剧日常 的微博，内容为 蔡徐坤这个大C位是不是拿的也不是多光彩。其他人没什么咖的赶脚。
# 已获取用户 茶美丽的追剧日常 的微博，内容为 纯甄热转数据统计前十杨紫是唯一的女艺人是不是因为她代言这个，所以爱丽丝不想给她代言的产品贡献热度？
# 已获取用户 茶美丽的追剧日常 的微博，内容为 扁桃体发炎了🙃有没有推荐的药🙃
# 已获取用户 茶美丽的追剧日常 的微博，内容为 内娱女流量格局：迪丽热巴、杨紫、刘雨昕、鞠婧祎、虞书欣、赵露思至于排名，好像没有男流量那么绝对的断层第一，大家自己感受
# 已获取用户 茶美丽的追剧日常 的微博，内容为 #内娱男流量格局# 内娱男流量格局：一大二次三小：一大流量肖战，二次流量成毅、王一博，三小流量龚俊、王鹤棣、刘宇宁大家是否认同？
# 已获取用户 茶美丽的追剧日常 的微博，内容为 明天王鹤棣和龚俊官宣还是要看看的然鹅大家口口相传的次顶流成毅这次为什么如此低调
# 已获取用户 茶美丽的追剧日常 的微博，内容为 #杨洋直播#杨洋是不是冷脸比笑更好看？
# 已获取用户 茶美丽的追剧日常 的微博，内容为 听说明天的battlefield是CPB！这个牌子据说是蔡徐坤代言的so～exciting！
# ------------------------------已获取茶美丽的追剧日常(6028429521)的第1页微博------------------------------
# Progress:   1%|          | 1/197 [00:08<27:20,  8.37s/it]
# ...
